# %% [markdown]
# <a href="https://colab.research.google.com/github/myrout/HEART-DISEASE-ANALYSIS-DASHBOARD/blob/main/Copy_of_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_excel("/content/Amazon-Sales-Report-40K-Rows.xlsx")
df
# Out:
#        index             Order ID       Date                        Status  \
# 0          0  405-8078784-5731545 2022-04-30                     Cancelled
# 1          1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2          2  404-0687676-7273146 2022-04-30                       Shipped
# 3          3  403-9615377-8133951 2022-04-30                     Cancelled
# 4          4  407-1069790-7240320 2022-04-30                       Shipped
# ...      ...                  ...        ...                           ...
# 79994  79993  405-4281911-1397935 2022-05-07                       Shipped
# 79995  79994  405-6956549-5429954 2022-05-07                       Shipped
# 79996  79995  408-3362245-5943546 2022-05-07  Shipped - Delivered to Buyer
# 79997  79996  171-7407233-2201932 2022-05-07                     Cancelled
# 79998  79997  402-9329422-9597167 2022-05-07                       Shipped
#
#       Fulfilment Sales Channel ship-service-level  Category Size  \
# ...

# %%
df.shape
# Out:
# (79999, 19)

# %%
df.head(50)
# Out:
#     index             Order ID       Date                        Status  \
# 0       0  405-8078784-5731545 2022-04-30                     Cancelled
# 1       1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2       2  404-0687676-7273146 2022-04-30                       Shipped
# 3       3  403-9615377-8133951 2022-04-30                     Cancelled
# 4       4  407-1069790-7240320 2022-04-30                       Shipped
# 5       5  404-1490984-4578765 2022-04-30                       Shipped
# 6       6  408-5748499-6859555 2022-04-30                       Shipped
# 7       7  406-7807733-3785945 2022-04-30  Shipped - Delivered to Buyer
# 8       8  407-5443024-5233168 2022-04-30                     Cancelled
# 9       9  402-4393761-0311520 2022-04-30                       Shipped
# 10     10  407-5633625-6970741 2022-04-30                       Shipped
# 11     11  171-4638481-6326716 2022-04-30                       Shipped
# ...

# %%
df.tail(20)
# Out:
#        index             Order ID       Date                        Status  \
# 79979  79978  407-0597159-4421147 2022-05-07  Shipped - Delivered to Buyer
# 79980  79979  407-0054630-2222720 2022-05-07                       Shipped
# 79981  79980  408-3393204-3525939 2022-05-07                       Shipped
# 79982  79981  407-6187138-0028316 2022-05-07                       Shipped
# 79983  79982  405-5593233-5382718 2022-05-07  Shipped - Delivered to Buyer
# 79984  79983  408-8903670-0165124 2022-05-07                       Shipped
# 79985  79984  405-7176874-6133147 2022-05-07                       Shipped
# 79986  79985  406-4227337-6788345 2022-05-07                       Shipped
# 79987  79986  406-4227337-6788345 2022-05-07                       Shipped
# 79988  79987  406-4227337-6788345 2022-05-07                       Shipped
# 79989  79988  407-0555096-3498749 2022-05-07                       Shipped
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79999 entries, 0 to 79998
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               79999 non-null  int64
#  1   Order ID            79999 non-null  object
#  2   Date                79999 non-null  datetime64[ns]
#  3   Status              79999 non-null  object
#  4   Fulfilment          79999 non-null  object
#  5   Sales Channel       79999 non-null  object
#  6   ship-service-level  79999 non-null  object
#  7   Category            79999 non-null  object
#  8   Size                79999 non-null  object
#  9   Courier Status      79999 non-null  object
#  10  Qty                 79999 non-null  int64
#  11  currency            75236 non-null  object
#  12  Amount              75236 non-null  float64
#  13  ship-city           79977 non-null  object
#  14  ship-state          79977 non-null  object
# ...

# %%
df.drop(['new','pending'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3559531571.py in <cell line: 0>()
# ----> 1 df.drop(['new','pending'],axis=1)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.info
# Out:
#        index             Order ID       Date                        Status  \
# 0          0  405-8078784-5731545 2022-04-30                     Cancelled
# 1          1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2          2  404-0687676-7273146 2022-04-30                       Shipped
# 3          3  403-9615377-8133951 2022-04-30                     Cancelled
# 4          4  407-1069790-7240320 2022-04-30                       Shipped
# ...      ...                  ...        ...                           ...
# 79994  79993  405-4281911-1397935 2022-05-07                       Shipped
# 79995  79994  405-6956549-5429954 2022-05-07                       Shipped
# 79996  79995  408-3362245-5943546 2022-05-07  Shipped - Delivered to Buyer
# 79997  79996  171-7407233-2201932 2022-05-07                     Cancelled
# 79998  79997  402-9329422-9597167 2022-05-07                       Shipped
#
#       Fulfilment Sales Channel ship-service-level  Category Size  \
# ...

# %%
pd.isnull(df)
# Out:
#        index  Order ID   Date  Status  Fulfilment  Sales Channel  \
# 0      False     False  False   False       False          False
# 1      False     False  False   False       False          False
# 2      False     False  False   False       False          False
# 3      False     False  False   False       False          False
# 4      False     False  False   False       False          False
# ...      ...       ...    ...     ...         ...            ...
# 79994  False     False  False   False       False          False
# 79995  False     False  False   False       False          False
# 79996  False     False  False   False       False          False
# 79997  False     False  False   False       False          False
# 79998  False     False  False   False       False          False
#
#        ship-service-level  Category   Size  Courier Status    Qty  currency  \
# 0                   False     False  False           False  False     False
# ...

# %%
pd.isnull(df).sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Category                  0
# Size                      0
# Courier Status            0
# Qty                       0
# currency               4763
# Amount                 4763
# ship-city                22
# ship-state               22
# ship-postal-code         22
# ship-country             22
# B2B                       0
# fulfilled-by          53376
# dtype: int64

# %%
df.shape
# Out:
# (79999, 19)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (25446, 19)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
df['ship-postal-code']=df['ship-postal-code'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25446 entries, 0 to 79996
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               25446 non-null  int64
#  1   Order ID            25446 non-null  object
#  2   Date                25446 non-null  datetime64[ns]
#  3   Status              25446 non-null  object
#  4   Fulfilment          25446 non-null  object
#  5   Sales Channel       25446 non-null  object
#  6   ship-service-level  25446 non-null  object
#  7   Category            25446 non-null  object
#  8   Size                25446 non-null  object
#  9   Courier Status      25446 non-null  object
#  10  Qty                 25446 non-null  int64
#  11  currency            25446 non-null  object
#  12  Amount              25446 non-null  float64
#  13  ship-city           25446 non-null  object
#  14  ship-state          25446 non-null  object
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25446 entries, 0 to 79996
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               25446 non-null  int64
#  1   Order ID            25446 non-null  object
#  2   Date                25446 non-null  datetime64[ns]
#  3   Status              25446 non-null  object
#  4   Fulfilment          25446 non-null  object
#  5   Sales Channel       25446 non-null  object
#  6   ship-service-level  25446 non-null  object
#  7   Category            25446 non-null  object
#  8   Size                25446 non-null  object
#  9   Courier Status      25446 non-null  object
#  10  Qty                 25446 non-null  int64
#  11  currency            25446 non-null  object
#  12  Amount              25446 non-null  float64
#  13  ship-city           25446 non-null  object
#  14  ship-state          25446 non-null  object
# ...

# %%
df.rename(columns={'Qty':Quantity})

# %%
df.describe()
# Out:
#               index                           Date      Quantity  \
# count  25446.000000                          25446  25446.000000
# mean   40391.136210  2022-04-29 05:31:20.216930048      0.866816
# min        0.000000            2022-03-31 00:00:00      0.000000
# 25%    18344.250000            2022-04-15 00:00:00      1.000000
# 50%    38874.500000            2022-04-26 00:00:00      1.000000
# 75%    64257.750000            2022-05-15 00:00:00      1.000000
# max    79995.000000            2022-05-31 00:00:00      5.000000
# std    24426.811813                            NaN      0.355494
#
#              Amount  ship-postal-code
# count  25446.000000      25446.000000
# mean     635.017956     459831.353651
# min        0.000000     110001.000000
# 25%      450.000000     334001.000000
# 50%      599.000000     500008.000000
# 75%      771.000000     600042.000000
# max     5495.000000     989898.000000
# std      277.824120     196712.773865

# %%
df.describe(include='object')
# Out:
#                    Order ID                        Status Fulfilment  \
# count                 25446                         25446      25446
# unique                23372                             8          1
# top     171-5057375-2831560  Shipped - Delivered to Buyer   Merchant
# freq                     12                         20401      25446
#
#        Sales Channel ship-service-level Category   Size Courier Status  \
# count          25446              25446    25446  25446          25446
# unique             1                  1        8     11              2
# top        Amazon.in           Standard    Shirt      M        Shipped
# freq           25446              25446     9594   4714          21945
#
#        currency  ship-city   ship-state ship-country fulfilled-by
# count     25446      25446        25446        25446        25446
# unique        1       3701           53            1            1
# ...

# %% [markdown]
# **Exploratory Data Analysis:**

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Quantity',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
ax=sns.countplot(x='Size',data=df)

for bars in ax.coantainers:
  ax.bar_label(bars)

# %% [markdown]
# **GROUP** **BY**

# %%
S_Quantity=df.groupby(['Size'],as_index=False)['Quantity'].sum().sort_values(by='Quantity',ascending=False)

# %%
sns.barplot(x='Size',y='Quantity',data=S_Quantity)
# Out:
# <Axes: xlabel='Size', ylabel='Quantity'>

# %%
sns.countplot(data=df, x='Courier Status',hue= 'Status')
# Out:
# <Axes: xlabel='Courier Status', ylabel='count'>

# %%
plt.figure(figsize=(5,5))

ax=sns.countplot(data=df, x='Courier Status',hue= 'Status')

plt.show()

# %%
df['Category'] = df['Category'].astype(str)
column_data = df['Category']
plt.figure(figsize=(5, 5))
plt.hist(column_data, bins=30, edgecolor='Black')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **From above Graph you can see that most of the buyers are T-SHIRT

# %%
# Checking B2B Data  by using pie chart
B2B_Check = df['B2B'].value_counts()

#  Plot the pie chart
plt.pie(B2B_Check, labels=B2B_Check.index, autopct='%1.1f%%')
#plt.axis('equal')
plt.show()

# %%
#  Prepare data for pie chart
a1 = df['Fulfilment'].value_counts()

# Step 4: Plot the pie chart
fig, ax = plt.subplots()

ax.pie(a1, labels=a1.index, autopct='%1.1f%%', radius=0.7, wedgeprops=dict(width=0.6))
ax.set(aspect="equal")

plt.show()

# %%
# Prepare data for scatter plot
x_data = df['Category']
y_data = df['Size']

# Plot the scatter plot
plt.scatter(x_data, y_data)
plt.xlabel('Category ')
plt.ylabel('Size')
plt.title('Scatter Plot')
plt.show()

# %%
# Plot count of cities by state
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='ship-state')
plt.xlabel('ship-state')
plt.ylabel('count')
plt.title('Distribution of State')
plt.xticks(rotation=90)
plt.show()

# %%
# top_5_States
top_10_state = df['ship-state'].value_counts().head(5)
# Plot count of cities by state
plt.figure(figsize=(12, 6))
sns.countplot(data=df[df['ship-state'].isin(top_10_state.index)], x='ship-state')
plt.xlabel('ship-state')
plt.ylabel('count')
plt.title('Distribution of  State')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Note:** **From above Graph you can see that most of th**e  **buyers are**  **Maharashtra state**
# **Conclusion**
# **The data analysis reveals that the business has a significant customer base in Maharashtra state**, **mainly serves retailers, fulfills orders through Amazon, experiences high demand for T-shirts,** **and sees M-Size as the** **preferred choice among buyers**.
